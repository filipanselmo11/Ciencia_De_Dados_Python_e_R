# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
base = pd.read_csv('./Dados_dashboards/trees.csv')

# %%
h = np.histogram(base.iloc[:, 1], bins=2)
h
# Out:
# (array([11, 20]), array([63., 75., 87.]))

# %%
#Histograma
plt.hist(base.iloc[:,1], bins=10)
plt.title("Arvores")
plt.ylabel("Frequencia")
plt.xlabel("Altura")
# Out:
# Text(0.5, 0, 'Altura')

# %%
#Gráfico de densidade
sns.distplot(base.iloc[:,1], hist=True, kde=True,
    bins=6, color="blue", hist_kws={'edgeColor': 'black'})

# %%
#Gŕafico de dispersão
plt.scatter(base.Girth, base.Volume, color="blue",
    facecolors='none')#Ver documentação para mais detalhes
plt.title("Arvores")
plt.xlabel("Volume")
plt.ylabel("Girth")
# Out:
# Text(0, 0.5, 'Girth')

# %%
#Gráfico de Linha
plt.plot(base.Girth, base.Volume)

# %%
sns.regplot(base.Girth, base.Volume, data=base,
    x_jitter=0.3, fit_reg=False)

# %%
#Dispersão com legendas
base2 = pd.read_csv('./Dados_dashboards/co2.csv')

# %%
x = base2.conc
y = base2.uptake

unicos = list(set(base2.Treatment))
unicos
# Out:
# ['chilled', 'nonchilled']

# %%
for i in range(len(unicos)):
    indice = base2.Treatment == unicos[i]
    plt.scatter(x[indice], y[indice], label=unicos[i])
plt.legend(loc='lower right')

# %%
base.head()
# Out:
#    Girth  Height  Volume
# 0    8.3      70    10.3
# 1    8.6      65    10.3
# 2    8.8      63    10.2
# 3   10.5      72    16.4
# 4   10.7      81    18.8

# %%
#Divisão de telas
plt.figure(1)
#girth com volume
plt.subplot(2,2,1)
plt.scatter(base.Girth, base.Volume)

plt.subplot(2,2,2)
plt.scatter(base.Girth, base.Height)

plt.subplot(2,2,3)
plt.scatter(base.Height, base.Volume)

plt.subplot(2,2,4)
plt.hist(base.Volume)
# Out:
# (array([ 5., 10.,  4.,  4.,  2.,  0.,  4.,  1.,  0.,  1.]),
#  array([10.2 , 16.88, 23.56, 30.24, 36.92, 43.6 , 50.28, 56.96, 63.64,
#         70.32, 77.  ]),
#  <a list of 10 Patch objects>)

# %%
#Boxplot
plt.boxplot(base.Volume, vert=False, showfliers=False,
    notch=True, patch_artist=True)
plt.title("Arvores")
plt.xlabel("Volume")
# Out:
# Text(0.5, 0, 'Volume')

# %%
plt.boxplot(base)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f65218b6630>,
#   <matplotlib.lines.Line2D at 0x7f65218b6978>,
#   <matplotlib.lines.Line2D at 0x7f6521c13d68>,
#   <matplotlib.lines.Line2D at 0x7f6521c13e48>,
#   <matplotlib.lines.Line2D at 0x7f6521c3a4e0>,
#   <matplotlib.lines.Line2D at 0x7f6521c3a828>,
#   <matplotlib.lines.Line2D at 0x7f6521954c18>,
#   <matplotlib.lines.Line2D at 0x7f6521954f60>,
#   <matplotlib.lines.Line2D at 0x7f6521968f98>,
#   <matplotlib.lines.Line2D at 0x7f652197a6d8>,
#   <matplotlib.lines.Line2D at 0x7f652200aac8>,
#   <matplotlib.lines.Line2D at 0x7f652200ae10>,
#   <matplotlib.lines.Line2D at 0x7f6522024f60>,
#   <matplotlib.lines.Line2D at 0x7f6522034588>,
#   <matplotlib.lines.Line2D at 0x7f6521e0b978>,
#   <matplotlib.lines.Line2D at 0x7f6521e0bcc0>,
#   <matplotlib.lines.Line2D at 0x7f6521e1be10>,
#   <matplotlib.lines.Line2D at 0x7f6521e36438>,
#   <matplotlib.lines.Line2D at 0x7f6521d86828>,
#   <matplotlib.lines.Line2D at 0x7f6521d86b70>,
#   <matplotlib.lines.Line2D at 0x7f6521d98f60>,
#   <matplotlib.lines.Line2D at 0x7f6521d98f28>,
#   <matplotlib.lines.Line2D at 0x7f6521c886d8>,
#   <matplotlib.lines.Line2D at 0x7f6521c88a20>,
#   <matplotlib.lines.Line2D at 0x7f6521c97e10>,
#   <matplotlib.lines.Line2D at 0x7f6521c97ef0>,
#   <matplotlib.lines.Line2D at 0x7f6521cbd588>,
#   <matplotlib.lines.Line2D at 0x7f6521cbd8d0>,
#   <matplotlib.lines.Line2D at 0x7f6521b90cc0>,
#   <matplotlib.lines.Line2D at 0x7f6521b90da0>,
#   <matplotlib.lines.Line2D at 0x7f6521ba6f28>,
#   <matplotlib.lines.Line2D at 0x7f6521bb95c0>,
#   <matplotlib.lines.Line2D at 0x7f6521b50898>,
#   <matplotlib.lines.Line2D at 0x7f6521b50b70>,
#   <matplotlib.lines.Line2D at 0x7f6521b61e48>,
#   <matplotlib.lines.Line2D at 0x7f6521b61f28>,
#   <matplotlib.lines.Line2D at 0x7f6521fce438>,
#   <matplotlib.lines.Line2D at 0x7f6521fce710>,
#   <matplotlib.lines.Line2D at 0x7f6521feb9e8>,
#   <matplotlib.lines.Line2D at 0x7f6521febcc0>,
#   <matplotlib.lines.Line2D at 0x7f6522003f98>,
#   <matplotlib.lines.Line2D at 0x7f6522003f60>,
#   <matplotlib.lines.Line2D at 0x7f6521efb588>,
#   <matplotlib.lines.Line2D at 0x7f6521efb860>,
#   <matplotlib.lines.Line2D at 0x7f6521e91b38>,
#   <matplotlib.lines.Line2D at 0x7f6521e91e10>,
#   <matplotlib.lines.Line2D at 0x7f6521eb0e80>,
#   <matplotlib.lines.Line2D at 0x7f6521ec0400>,
#   <matplotlib.lines.Line2D at 0x7f6521e606d8>,
#   <matplotlib.lines.Line2D at 0x7f6521e609b0>,
#   <matplotlib.lines.Line2D at 0x7f6521e78c88>,
#   <matplotlib.lines.Line2D at 0x7f6521e78f60>,
#   <matplotlib.lines.Line2D at 0x7f6521dd1fd0>,
#   <matplotlib.lines.Line2D at 0x7f6521df6550>,
#   <matplotlib.lines.Line2D at 0x7f6521d0d828>,
#   <matplotlib.lines.Line2D at 0x7f6521d0db00>,
#   <matplotlib.lines.Line2D at 0x7f6521d27dd8>,
#   <matplotlib.lines.Line2D at 0x7f6521d27eb8>,
#   <matplotlib.lines.Line2D at 0x7f6521bdb3c8>,
#   <matplotlib.lines.Line2D at 0x7f6521bdb6a0>,
#   <matplotlib.lines.Line2D at 0x7f6521bf7978>,
#   <matplotlib.lines.Line2D at 0x7f6521bf7c50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f65218b6cc0>,
#   <matplotlib.lines.Line2D at 0x7f65218b6da0>,
#   <matplotlib.lines.Line2D at 0x7f6521c29438>,
#   <matplotlib.lines.Line2D at 0x7f6521c29780>,
#   <matplotlib.lines.Line2D at 0x7f6521c3ab70>,
#   <matplotlib.lines.Line2D at 0x7f6521c3aeb8>,
#   <matplotlib.lines.Line2D at 0x7f6521954ef0>,
#   <matplotlib.lines.Line2D at 0x7f6521968630>,
#   <matplotlib.lines.Line2D at 0x7f652197aa20>,
#   <matplotlib.lines.Line2D at 0x7f652197ad68>,
#   <matplotlib.lines.Line2D at 0x7f652200aef0>,
#   <matplotlib.lines.Line2D at 0x7f65220244e0>,
#   <matplotlib.lines.Line2D at 0x7f65220348d0>,
#   <matplotlib.lines.Line2D at 0x7f6522034c18>,
#   <matplotlib.lines.Line2D at 0x7f6521e0bda0>,
#   <matplotlib.lines.Line2D at 0x7f6521e1b390>,
#   <matplotlib.lines.Line2D at 0x7f6521e36780>,
#   <matplotlib.lines.Line2D at 0x7f6521e36ac8>,
#   <matplotlib.lines.Line2D at 0x7f6521d86eb8>,
#   <matplotlib.lines.Line2D at 0x7f6521d86f98>,
#   <matplotlib.lines.Line2D at 0x7f6521da7630>,
#   <matplotlib.lines.Line2D at 0x7f6521da7978>,
#   <matplotlib.lines.Line2D at 0x7f6521c88d68>,
#   <matplotlib.lines.Line2D at 0x7f6521c88e48>,
#   <matplotlib.lines.Line2D at 0x7f6521ca74e0>,
#   <matplotlib.lines.Line2D at 0x7f6521ca7828>,
#   <matplotlib.lines.Line2D at 0x7f6521cbdc18>,
#   <matplotlib.lines.Line2D at 0x7f6521cbdf60>,
#   <matplotlib.lines.Line2D at 0x7f6521b90fd0>,
#   <matplotlib.lines.Line2D at 0x7f6521ba6630>,
#   <matplotlib.lines.Line2D at 0x7f6521bb98d0>,
#   <matplotlib.lines.Line2D at 0x7f6521bb9be0>,
#   <matplotlib.lines.Line2D at 0x7f6521b50e80>,
#   <matplotlib.lines.Line2D at 0x7f6521b50f98>,
#   <matplotlib.lines.Line2D at 0x7f6521b75470>,
#   <matplotlib.lines.Line2D at 0x7f6521b75780>,
#   <matplotlib.lines.Line2D at 0x7f6521fcea20>,
#   <matplotlib.lines.Line2D at 0x7f6521fced30>,
#   <matplotlib.lines.Line2D at 0x7f6521febdd8>,
#   <matplotlib.lines.Line2D at 0x7f6521febfd0>,
#   <matplotlib.lines.Line2D at 0x7f6521ee55c0>,
#   <matplotlib.lines.Line2D at 0x7f6521ee58d0>,
#   <matplotlib.lines.Line2D at 0x7f6521efbb70>,
#   <matplotlib.lines.Line2D at 0x7f6521efbe80>,
#   <matplotlib.lines.Line2D at 0x7f6521e91f28>,
#   <matplotlib.lines.Line2D at 0x7f6521eb0470>,
#   <matplotlib.lines.Line2D at 0x7f6521ec0710>,
#   <matplotlib.lines.Line2D at 0x7f6521ec0a20>,
#   <matplotlib.lines.Line2D at 0x7f6521e60cc0>,
#   <matplotlib.lines.Line2D at 0x7f6521e60dd8>,
#   <matplotlib.lines.Line2D at 0x7f6521e78f98>,
#   <matplotlib.lines.Line2D at 0x7f6521dd15c0>,
#   <matplotlib.lines.Line2D at 0x7f6521df6860>,
#   <matplotlib.lines.Line2D at 0x7f6521df6b70>,
#   <matplotlib.lines.Line2D at 0x7f6521d0de10>,
#   <matplotlib.lines.Line2D at 0x7f6521d0df28>,
#   <matplotlib.lines.Line2D at 0x7f6521d3f400>,
#   <matplotlib.lines.Line2D at 0x7f6521d3f710>,
#   <matplotlib.lines.Line2D at 0x7f6521bdb9b0>,
#   <matplotlib.lines.Line2D at 0x7f6521bdbcc0>,
#   <matplotlib.lines.Line2D at 0x7f6521bf7f60>,
#   <matplotlib.lines.Line2D at 0x7f6521bf7f98>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f65218b6208>,
#   <matplotlib.lines.Line2D at 0x7f6521c139e8>,
#   <matplotlib.lines.Line2D at 0x7f6521c29e80>,
#   <matplotlib.lines.Line2D at 0x7f6521954898>,
#   <matplotlib.lines.Line2D at 0x7f6521968fd0>,
#   <matplotlib.lines.Line2D at 0x7f652200a748>,
#   <matplotlib.lines.Line2D at 0x7f6522024e80>,
#   <matplotlib.lines.Line2D at 0x7f6521e0b5f8>,
#   <matplotlib.lines.Line2D at 0x7f6521e1bd30>,
#   <matplotlib.lines.Line2D at 0x7f6521d864a8>,
#   <matplotlib.lines.Line2D at 0x7f6521d98be0>,
#   <matplotlib.lines.Line2D at 0x7f6521c88358>,
#   <matplotlib.lines.Line2D at 0x7f6521c97a90>,
#   <matplotlib.lines.Line2D at 0x7f6521ca7f28>,
#   <matplotlib.lines.Line2D at 0x7f6521b90940>,
#   <matplotlib.lines.Line2D at 0x7f6521ba6f60>,
#   <matplotlib.lines.Line2D at 0x7f6521b50550>,
#   <matplotlib.lines.Line2D at 0x7f6521b61b00>,
#   <matplotlib.lines.Line2D at 0x7f6521b75e48>,
#   <matplotlib.lines.Line2D at 0x7f6521feb6a0>,
#   <matplotlib.lines.Line2D at 0x7f6522003c50>,
#   <matplotlib.lines.Line2D at 0x7f6521ee5f98>,
#   <matplotlib.lines.Line2D at 0x7f6521e917f0>,
#   <matplotlib.lines.Line2D at 0x7f6521eb0da0>,
#   <matplotlib.lines.Line2D at 0x7f6521e60390>,
#   <matplotlib.lines.Line2D at 0x7f6521e78940>,
#   <matplotlib.lines.Line2D at 0x7f6521dd1ef0>,
#   <matplotlib.lines.Line2D at 0x7f6521d0d4e0>,
#   <matplotlib.lines.Line2D at 0x7f6521d27a90>,
#   <matplotlib.lines.Line2D at 0x7f6521d3fdd8>,
#   <matplotlib.lines.Line2D at 0x7f6521bf7630>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6521c13390>,
#   <matplotlib.lines.Line2D at 0x7f6521c29ac8>,
#   <matplotlib.lines.Line2D at 0x7f6521c3af98>,
#   <matplotlib.lines.Line2D at 0x7f6521968978>,
#   <matplotlib.lines.Line2D at 0x7f652197ae48>,
#   <matplotlib.lines.Line2D at 0x7f6522024828>,
#   <matplotlib.lines.Line2D at 0x7f6522034f60>,
#   <matplotlib.lines.Line2D at 0x7f6521e1b6d8>,
#   <matplotlib.lines.Line2D at 0x7f6521e36e10>,
#   <matplotlib.lines.Line2D at 0x7f6521d98588>,
#   <matplotlib.lines.Line2D at 0x7f6521da7cc0>,
#   <matplotlib.lines.Line2D at 0x7f6521c97438>,
#   <matplotlib.lines.Line2D at 0x7f6521ca7b70>,
#   <matplotlib.lines.Line2D at 0x7f6521cbdef0>,
#   <matplotlib.lines.Line2D at 0x7f6521ba6940>,
#   <matplotlib.lines.Line2D at 0x7f6521bb9ef0>,
#   <matplotlib.lines.Line2D at 0x7f6521b614e0>,
#   <matplotlib.lines.Line2D at 0x7f6521b75a90>,
#   <matplotlib.lines.Line2D at 0x7f6521fcee48>,
#   <matplotlib.lines.Line2D at 0x7f6522003630>,
#   <matplotlib.lines.Line2D at 0x7f6521ee5be0>,
#   <matplotlib.lines.Line2D at 0x7f6521efbf98>,
#   <matplotlib.lines.Line2D at 0x7f6521eb0780>,
#   <matplotlib.lines.Line2D at 0x7f6521ec0d30>,
#   <matplotlib.lines.Line2D at 0x7f6521e60fd0>,
#   <matplotlib.lines.Line2D at 0x7f6521dd18d0>,
#   <matplotlib.lines.Line2D at 0x7f6521df6e80>,
#   <matplotlib.lines.Line2D at 0x7f6521d27470>,
#   <matplotlib.lines.Line2D at 0x7f6521d3fa20>,
#   <matplotlib.lines.Line2D at 0x7f6521bdbdd8>,
#   <matplotlib.lines.Line2D at 0x7f6521acd5c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6521c136a0>,
#   <matplotlib.lines.Line2D at 0x7f6521c29dd8>,
#   <matplotlib.lines.Line2D at 0x7f6521954550>,
#   <matplotlib.lines.Line2D at 0x7f6521968c88>,
#   <matplotlib.lines.Line2D at 0x7f652200a400>,
#   <matplotlib.lines.Line2D at 0x7f6522024b38>,
#   <matplotlib.lines.Line2D at 0x7f6522034ef0>,
#   <matplotlib.lines.Line2D at 0x7f6521e1b9e8>,
#   <matplotlib.lines.Line2D at 0x7f6521e36ef0>,
#   <matplotlib.lines.Line2D at 0x7f6521d98898>,
#   <matplotlib.lines.Line2D at 0x7f6521da7fd0>,
#   <matplotlib.lines.Line2D at 0x7f6521c97748>,
#   <matplotlib.lines.Line2D at 0x7f6521ca7e80>,
#   <matplotlib.lines.Line2D at 0x7f6521b905f8>,
#   <matplotlib.lines.Line2D at 0x7f6521ba6c88>,
#   <matplotlib.lines.Line2D at 0x7f6521bb9f28>,
#   <matplotlib.lines.Line2D at 0x7f6521b61828>,
#   <matplotlib.lines.Line2D at 0x7f6521b75dd8>,
#   <matplotlib.lines.Line2D at 0x7f6521feb3c8>,
#   <matplotlib.lines.Line2D at 0x7f6522003978>,
#   <matplotlib.lines.Line2D at 0x7f6521ee5f28>,
#   <matplotlib.lines.Line2D at 0x7f6521e91518>,
#   <matplotlib.lines.Line2D at 0x7f6521eb0ac8>,
#   <matplotlib.lines.Line2D at 0x7f6521ec0e48>,
#   <matplotlib.lines.Line2D at 0x7f6521e78668>,
#   <matplotlib.lines.Line2D at 0x7f6521dd1c18>,
#   <matplotlib.lines.Line2D at 0x7f6521df6f98>,
#   <matplotlib.lines.Line2D at 0x7f6521d277b8>,
#   <matplotlib.lines.Line2D at 0x7f6521d3fd68>,
#   <matplotlib.lines.Line2D at 0x7f6521bdbfd0>,
#   <matplotlib.lines.Line2D at 0x7f6521acd908>],
#  'means': []}

# %%
plt.boxplot(base.Volume, vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f6519e32198>,
#   <matplotlib.lines.Line2D at 0x7f6519e2d4e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f6519e2d0b8>,
#   <matplotlib.lines.Line2D at 0x7f6519e2d2b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f6519e32470>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6519e2f668>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6519e2f550>],
#  'means': []}

# %%
plt.boxplot(base.Girth, vert=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f6519b885c0>,
#   <matplotlib.lines.Line2D at 0x7f6519d24710>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f6519d34ba8>,
#   <matplotlib.lines.Line2D at 0x7f6519c66438>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f6519b88710>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f6519b81898>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f6519bfc908>],
#  'means': []}

# %%
#Gráficos de barras e setores
base3 = pd.read_csv('./Dados_dashboards/insect.csv')
base3
# Out:
#     count spray
# 0      10     A
# 1       7     A
# 2      20     A
# 3      14     A
# 4      14     A
# 5      12     A
# 6      10     A
# 7      23     A
# 8      17     A
# 9      20     A
# 10     14     A
# 11     13     A
# 12     11     B
# 13     17     B
# 14     21     B
# 15     11     B
# 16     16     B
# 17     14     B
# 18     17     B
# 19     17     B
# 20     19     B
# 21     21     B
# 22      7     B
# 23     13     B
# 24      0     C
# 25      1     C
# 26      7     C
# 27      2     C
# 28      3     C
# 29      1     C
# ..    ...   ...
# 42      5     D
# 43      5     D
# 44      5     D
# 45      5     D
# 46      2     D
# 47      4     D
# 48      3     E
# 49      5     E
# 50      3     E
# 51      5     E
# 52      3     E
# 53      6     E
# 54      1     E
# 55      1     E
# 56      3     E
# 57      2     E
# 58      6     E
# 59      4     E
# 60     11     F
# 61      9     F
# 62     15     F
# 63     22     F
# 64     15     F
# 65     16     F
# 66     13     F
# 67     10     F
# 68     26     F
# 69     26     F
# 70     24     F
# 71     13     F
#
# [72 rows x 2 columns]

# %%
agrupado = base3.groupby(['spray'])['count'].sum()
agrupado
# Out:
# spray
# A    174
# B    184
# C     25
# D     59
# E     42
# F    200
# Name: count, dtype: int64

# %%
agrupado.plot.bar(color='gray')

# %%
agrupado.plot.pie(legend=True)

# %%
#Mais boxplot
sns.boxplot(base.Volume).set_title("Arvores")
# Out:
# Text(0.5, 1.0, 'Arvores')

# %%
sns.boxplot(data = base)

# %%
#hisatograma e densidade
